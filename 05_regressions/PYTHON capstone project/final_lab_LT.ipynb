# %% [markdown]
# # Pardavimų ir klientų elgsenos analizė

# %% [markdown]
# ## Projekto tikslas
#
# Pritaikyti pagrindinius duomenų analizės, statistikos ir
# modeliavimo metodus, atliekant pilną analizės ciklą: nuo duomenų supratimo iki
# statistinių išvadų ir prognozavimo Python aplinkoje.

# %% [markdown]
# ## Duomenų rinkinys
#
# **Supermarket Sales Dataset (Kaggle)**
#
# https://www.kaggle.com/datasets/faresashraf1001/supermarket-sales

# %% [markdown]
# ## Techniniai reikalavimai
#
# - Analitinis darbas pateikiamas **Jupyter Notebook** formatu (.ipynb) ir analitinės
#   išvados pdf arba word.
# - Kodas turi būti tvarkingas ir nuoseklus;
# - Visi rezultatai turi būti paaiškinti tekstu;
# - Akcentuojamas aiškumas ir teisinga logika, kuriama vertė verslui.

# %% [markdown]
# ## Analizės etapai

# %% [markdown]
# ---

# %% [markdown]
# ### 1. Duomenų supratimas ir paruošimas
#
# **Reikia:**
#
# - įkelti duomenų rinkinį;
# - trumpai aprašyti duomenis ir kintamuosius;
# - patikrinti duomenų struktūrą (dydį, stulpelius, duomenų tipus);
# - įvertinti, ar yra trūkstamų reikšmių ar akivaizdžių duomenų problemų.
#
# **Rezultatas:** trumpas tekstinis aprašymas ir bazinė duomenų apžvalga.

# %% [markdown]
# ### Sprendimas:

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("./data/SuperMarketAnalysis.csv")
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428   Alex     Yangon        Member  Female
# 1  226-31-3081   Giza  Naypyitaw        Normal  Female
# 2  631-41-3108   Alex     Yangon        Normal  Female
# 3  123-19-1176   Alex     Yangon        Member  Female
# 4  373-73-7910   Alex     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Sales       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#           Time      Payment    cogs  gross margin percentage  gross income  \
# 0   1:08:00 PM      Ewallet  522.83                 4.761905       26.1415
# ...

# %% [markdown]
# Bendra informacija apie duomenis:

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   str
#  1   Branch                   1000 non-null   str
#  2   City                     1000 non-null   str
#  3   Customer type            1000 non-null   str
#  4   Gender                   1000 non-null   str
#  5   Product line             1000 non-null   str
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Sales                    1000 non-null   float64
#  10  Date                     1000 non-null   str
#  11  Time                     1000 non-null   str
#  12  Payment                  1000 non-null   str
#  13  cogs                     1000 non-null   float64
# ...

# %% [markdown]
# Duomenų rinkinio eilučių ir stulpelių skaičius:

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# Stulpelių pavadinimai:

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Sales', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='str')

# %% [markdown]
# Duomenų tipai kiekviename stulpelyje:

# %%
df.dtypes
# Out:
# Invoice ID                     str
# Branch                         str
# City                           str
# Customer type                  str
# Gender                         str
# Product line                   str
# Unit price                 float64
# Quantity                     int64
# Tax 5%                     float64
# Sales                      float64
# Date                           str
# Time                           str
# Payment                        str
# cogs                       float64
# gross margin percentage    float64
# gross income               float64
# Rating                     float64
# dtype: object

# %% [markdown]
# Duomenys neturi trūkstamų reikšmių:

# %%
df.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Sales                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# Kiti pastebėjimai:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 2. Aprašomoji analizė (EDA)
#
# **Reikia:**
#
# - apskaičiuoti pagrindines statistines metrikas bent vienam skaitiniam kintamajam:
#   - vidurkį,
#   - medianą,
#   - standartinį nuokrypį,
#   - minimumą ir maksimumą;
# - pateikti bent 3-5 aiškius grafikus (pvz., pardavimų pasiskirstymas, pardavimai pagal
#   miestą ar produktų liniją);
# - trumpai paaiškinti, ką šie rezultatai rodo.

# %% [markdown]
# ### Sprendimas:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 3. Pasikliautiniai intervalai
#
# **Reikia:**
#
# - pasirinkti vieną skaitinį kintamąjį (pvz., Total, gross income arba Rating);
# - apskaičiuoti 95 % pasikliautinį intervalą jo vidurkiui;
# - paaiškinti, kaip šį intervalą interpretuoti praktiniame kontekste.

# %% [markdown]
# ### Sprendimas:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 4. Hipotezių testavimas
#
# Reikia atlikti **bent vieną** statistinį hipotezių testą.
#
# **Galimi pavyzdžiai:**
#
# - t-test: vidutinės pirkimo sumos palyginimas tarp Customer type (Member vs Normal);
# - ANOVA: vidutinių pardavimų ar pajamų palyginimas tarp Branch;
# - Chi-square testas: ryšio tarp dviejų kategorinių kintamųjų (pvz., Payment ir Gender) įvertinimas.
#
# **Reikia:**
#
# - aiškiai suformuluoti H0 ir Ha;
# - pateikti p reikšmę;
# - atlikti įžvalgų interpretaciją.

# %% [markdown]
# ### Sprendimas:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 5. Analitinė dalis

# %% [markdown]
# #### A. Regresinė analizė
#
# - pasirinkti target kintamąjį (pvz., Total);
# - sukurti regresijos modelį;
# - įvertinti modelio kokybę (pvz., R², MAE arba RMSE);
# - trumpai interpretuoti rezultatus.

# %% [markdown]
# ### Sprendimas:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### B. Laiko eilučių analizė
#
# - agreguoti pardavimus pagal laiką (dienas arba mėnesius);
# - pavaizduoti pardavimų dinamiką;
# - aprašyti stebimas tendencijas ar sezoniškumą;
# - pateikti nesudėtingą prognozės pavyzdį.

# %% [markdown]
# ### Sprendimas:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### 6. Išvados
#
# **Reikia:**
#
# - apibendrinti pagrindinius analizės rezultatus;
# - paaiškinti, kuo šios įžvalgos gali būti naudingos verslui;
# - pateikti aiškias ir trumpas išvadas/dokumentaciją pdf ar word (1-3 puslapiai).

# %% [markdown]
# ### Sprendimas:

# %%
# TODO
# ...
# ...

# %% [markdown]
# ---
