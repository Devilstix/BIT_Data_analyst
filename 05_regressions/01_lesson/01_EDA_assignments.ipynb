# %% [markdown]
# # Assignment 1: Basic EDA
#
# 1. Read in the "Computers.csv" file.
# 2. Explore the target variable, "price". Look at a histogram and boxplot of it.
# 3. Then, produce histograms of the 'speed' and 'ram' variables.
# 4. Feel free to further explore the dataset!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

computers = pd.read_csv(r"C:\BIT_Data_analyst\05_regressions\01_lesson\Computers.csv")

computers.head()
# Out:
#    price  speed   hd  ram  screen  cd multi premium  ads  trend
# 0   1499     25   80    4      14  no    no     yes   94      1
# 1   1795     33   85    2      14  no    no     yes   94      1
# 2   1595     25  170    4      15  no    no     yes   94      1
# 3   1849     25  170    8      14  no    no      no   94      1
# 4   3295     33  340   16      14  no    no     yes   94      1

# %%
computers.describe().T
# Out:
#          count         mean         std    min     25%     50%     75%     max
# price   6259.0  2219.576610  580.803956  949.0  1794.0  2144.0  2595.0  5399.0
# speed   6259.0    52.011024   21.157735   25.0    33.0    50.0    66.0   100.0
# hd      6259.0   416.601694  258.548445   80.0   214.0   340.0   528.0  2100.0
# ram     6259.0     8.286947    5.631099    2.0     4.0     8.0     8.0    32.0
# screen  6259.0    14.608723    0.905115   14.0    14.0    14.0    15.0    17.0
# ads     6259.0   221.301007   74.835284   39.0   162.5   246.0   275.0   339.0
# trend   6259.0    15.926985    7.873984    1.0    10.0    16.0    21.5    35.0

# %%
plt.figure(figsize=(8,5))
sns.histplot(computers["price"], bins=30, kde=True)
plt.title("Price histogram")
plt.xlabel("Price")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=computers["price"])
plt.title("Price boxplot")
plt.xlabel("Price")
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxenplot(x=computers["price"])
plt.title("Price boxenplot")
plt.xlabel("Price")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.histplot(computers["speed"], kde=True)
plt.title("Speed histogram")
plt.xlabel("Speed (MHz)")
plt.show()

# %%
plt.figure(figsize=(9,5))
sns.histplot(computers["ram"], kde=True)
plt.title("RAM histogram")
plt.xlabel("RAM (MB)")
plt.show()

# %% [markdown]
# ## Assignment 2: Variable Relationships
#
# 1. Build a correlation matrix of numeric features and pass it into a heatmap
# 2. Build a pairplot of numeric features in the data. Hint: df.select_dtypes("number") selects numeric columns. Consider sampling with df.sample(1000) to speed this up if it takes too long.
# 3. Build an lmplot of ram vs. price. Does being a premium model (premium == 'yes') impact this relationship?

# %%
plt.figure(figsize=(10,6))
sns.heatmap(computers.corr(numeric_only=True), annot=True, cmap="viridis")
plt.title("Correlation matrix")
plt.show()

# %%
numeric = computers.select_dtypes("number")

sns.pairplot(numeric.sample(1000, random_state=1))
plt.show()

# %%
sns.lmplot(
    data=computers,
    x="ram",
    y="price",
    hue="premium",
    height=8,
    aspect=1.2
)
plt.title("RAM vs Price with Premium Indicator")
plt.show()

# %% [markdown]
# RAM padidina kainą vienodai abiem grupėms
# Premium statusas nekeičia to, kiek kainą pakelia papildomas RAM vienetas.
#
# Premium statusas tik prideda pastovų kainos priedą
# Tarsi „premium mokestis“, kuris galioja visame RAM diapazone.
