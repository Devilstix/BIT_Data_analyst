# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# For regression:
import statsmodels.api as sm
from scipy import stats
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
import matplotlib.dates as mdates
df = pd.read_csv(r"C:\BIT_Data_analyst\06_machine learning\06_lesson\customers.csv")

# %%
# create a sample dataframe
import pandas as pd
 
songs_dict = {
                'Customer': ['Aria', 'Aria', 'Aria', 'Chord', 'Chord', 'Harmony', 'Harmony', 'Harmony', 'Melody', 'Reed'],
                'Genre': ['Pop', 'Indie', 'Rock', 'Pop', 'Indie', 'Pop', 'Indie', 'Rock', 'Rock', 'Rock'],
                '# Songs': [50, 48, 1, 15, 36, 10, 5, 3, 2, 5]
             }
 
df = pd.DataFrame(songs_dict)
df
# Out:
#   Customer  Genre  # Songs
# 0     Aria    Pop       50
# 1     Aria  Indie       48
# 2     Aria   Rock        1
# 3    Chord    Pop       15
# 4    Chord  Indie       36
# 5  Harmony    Pop       10
# 6  Harmony  Indie        5
# 7  Harmony   Rock        3
# 8   Melody   Rock        2
# 9     Reed   Rock        5

# %%
df.groupby('Customer')['# Songs'].sum()
# Out:
# Customer
# Aria       99
# Chord      51
# Harmony    18
# Melody      2
# Reed        5
# Name: # Songs, dtype: int64

# %%
# use group by to sum up the songs for each customer
customers_songs = (df.groupby('Customer')['# Songs']
   .sum()
   .reset_index())
customers_songs
# Out:
#   Customer  # Songs
# 0     Aria       99
# 1    Chord       51
# 2  Harmony       18
# 3   Melody        2
# 4     Reed        5

# %%
df.pivot(index='Customer', columns='Genre', values='# Songs')
# Out:
# Genre     Indie   Pop  Rock
# Customer
# Aria       48.0  50.0   1.0
# Chord      36.0  15.0   NaN
# Harmony     5.0  10.0   3.0
# Melody      NaN   NaN   2.0
# Reed        NaN   NaN   5.0

# %%
# add on a fillna to remove the NaN values
(df.pivot(index='Customer',
          columns='Genre',
          values='# Songs')
    .fillna(0))
# Out:
# Genre     Indie   Pop  Rock
# Customer
# Aria       48.0  50.0   1.0
# Chord      36.0  15.0   0.0
# Harmony     5.0  10.0   3.0
# Melody      0.0   0.0   2.0
# Reed        0.0   0.0   5.0

# %%
# add on a reset_index to remove the multi-index
(df.pivot(index='Customer',
          columns='Genre',
          values='# Songs')
    .fillna(0)
    .reset_index())
# Out:
# Genre Customer  Indie   Pop  Rock
# 0         Aria   48.0  50.0   1.0
# 1        Chord   36.0  15.0   0.0
# 2      Harmony    5.0  10.0   3.0
# 3       Melody    0.0   0.0   2.0
# 4         Reed    0.0   0.0   5.0

# %%
# save the results as a new dataframe
customers_genres = (df.pivot(index='Customer',
                             columns='Genre',
                             values='# Songs')
                      .fillna(0)
                      .reset_index())
customers_genres
# Out:
# Genre Customer  Indie   Pop  Rock
# 0         Aria   48.0  50.0   1.0
# 1        Chord   36.0  15.0   0.0
# 2      Harmony    5.0  10.0   3.0
# 3       Melody    0.0   0.0   2.0
# 4         Reed    0.0   0.0   5.0

# %%
# create a dataframe that will hold clean data
customers = df.copy()
customers
# Out:
#   Customer  Genre  # Songs
# 0     Aria    Pop       50
# 1     Aria  Indie       48
# 2     Aria   Rock        1
# 3    Chord    Pop       15
# 4    Chord  Indie       36
# 5  Harmony    Pop       10
# 6  Harmony  Indie        5
# 7  Harmony   Rock        3
# 8   Melody   Rock        2
# 9     Reed   Rock        5

# %%
# rows with null values
customers.isna().any(axis=1)
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
customers.dropna()
# Out:
#   Customer  Genre  # Songs
# 0     Aria    Pop       50
# 1     Aria  Indie       48
# 2     Aria   Rock        1
# 3    Chord    Pop       15
# 4    Chord  Indie       36
# 5  Harmony    Pop       10
# 6  Harmony  Indie        5
# 7  Harmony   Rock        3
# 8   Melody   Rock        2
# 9     Reed   Rock        5

# %%
# and also remove the extra column
customers.dropna().reset_index(drop=True)
# Out:
#   Customer  Genre  # Songs
# 0     Aria    Pop       50
# 1     Aria  Indie       48
# 2     Aria   Rock        1
# 3    Chord    Pop       15
# 4    Chord  Indie       36
# 5  Harmony    Pop       10
# 6  Harmony  Indie        5
# 7  Harmony   Rock        3
# 8   Melody   Rock        2
# 9     Reed   Rock        5

# %%
customers_dropped_rows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 customers_dropped_rows
#
# NameError: name 'customers_dropped_rows' is not defined

# %%
customers[['Age', 'Followers']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 customers[['Age', 'Followers']]
#
# File c:\BIT_Data_analyst\venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File c:\BIT_Data_analyst\venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File c:\BIT_Data_analyst\venv\Lib\site-packages\pandas\core\indexes\base.py:6352, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6350 if nmissing:
#    6351     if nmissing == len(indexer):
# -> 6352         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6355     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['Age', 'Followers'], dtype='str')] are in the [columns]"

# %%
customers.Age.fillna(customers.Age.median())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29492\3827991605.py in ?()
# ----> 1 customers.Age.fillna(customers.Age.median())
#
# c:\BIT_Data_analyst\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Age'

# %%
round(customers.Age.fillna(customers.Age.median()))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29492\112850420.py in ?()
# ----> 1 round(customers.Age.fillna(customers.Age.median()))
#
# c:\BIT_Data_analyst\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Age'

# %%
customers.Followers.fillna(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29492\2766988362.py in ?()
# ----> 1 customers.Followers.fillna(0)
#
# c:\BIT_Data_analyst\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Followers'

# %%
customers.Age = round(customers.Age.fillna(customers.Age.median()))
customers.Followers = customers.Followers.fillna(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29492\1805296561.py in ?()
# ----> 1 customers.Age = round(customers.Age.fillna(customers.Age.median()))
#       2 customers.Followers = customers.Followers.fillna(0)
#
# c:\BIT_Data_analyst\venv\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Age'
